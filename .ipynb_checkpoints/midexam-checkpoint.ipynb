# %%
import pandas as pd
from sklearn import tree
from sklearn import feature_selection
from sklearn import linear_model
import graphviz
from IPython.display import display, Image

# %% [markdown]
# #### Load Dataset and Test Dataset

# %%
dataset = pd.read_csv(r'./titanic.csv')
test_dataset = pd.read_csv(r'./titanic_test.csv')
test_label_dataset = pd.read_csv(r'./titanic_testlabel.csv')

# %%
display(dataset)
display(test_dataset)
display(test_label_dataset)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
train_data = dataset.loc[:,['Sex', 'Age', 'Pclass', 'Fare', 'SibSp', 'Parch', 'Embarked']]
test_data = test_dataset.loc[:,['Sex', 'Age', 'Pclass', 'Fare', 'SibSp', 'Parch', 'Embarked']]

# %%
train_data['Sex'].replace({'male': 0, 'female': 1}, inplace = True)
test_data['Sex'].replace({'male': 0, 'female': 1}, inplace = True)

# %%
train_data['Embarked'].replace({'S': 0, 'C': 1, 'Q': 2}, inplace = True)
test_data['Embarked'].replace({'S': 0, 'C': 1, 'Q': 2}, inplace = True)

# %%
replacement_data = train_data.mean()
# Out:
# Sex         0.352413
# Pclass      2.308642
# SibSp       0.523008
# Parch       0.381594
# Embarked    0.362205
# dtype: float64

# %%
train_data = train_data.fillna(train_replacement_data)
test_data = test_data.fillna(train_replacement_data)

# %%
train_data.describe()
# Out:
#               Sex         Age      Pclass        Fare       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.352413   29.699118    2.308642   32.204208    0.523008    0.381594
# std      0.477990   13.002015    0.836071   49.693429    1.102743    0.806057
# min      0.000000    0.420000    1.000000    0.000000    0.000000    0.000000
# 25%      0.000000   22.000000    2.000000    7.910400    0.000000    0.000000
# 50%      0.000000   29.699118    3.000000   14.454200    0.000000    0.000000
# 75%      1.000000   35.000000    3.000000   31.000000    1.000000    0.000000
# max      1.000000   80.000000    3.000000  512.329200    8.000000    6.000000
#
#          Embarked
# count  891.000000
# mean     0.362205
# std      0.635442
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      2.000000

# %%
train_label = pd.concat([train_data, dataset['Survived']], axis = 1, join = "inner")['Survived']
test_label = pd.concat([test_data, test_label_dataset['Survived']], axis = 1, join = "inner")['Survived']

# %%
display(train_label)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
mdlsel = feature_selection.RFE(linear_model.LogisticRegression(solver='lbfgs', max_iter=200), n_features_to_select=5)
mdlsel.fit(train_data, train_label)
ix = mdlsel.get_support()
train_data = pd.DataFrame(mdlsel.transform(train_data), columns = train_data.columns.values[ix])
test_data = pd.DataFrame(mdlsel.transform(test_data), columns = test_data.columns.values[ix])

# %%
dtc = tree.DecisionTreeClassifier()
dtc.fit(train_data, train_label)
class_result = dtc.predict(test_data)
acc = dtc.score(test_data, test_label)
err = round((1 - acc) * 100, 2)

# %%
print("Used features : " + str(train_data.columns))
print("Error Rate : " + str(err))
# Out:
# Used features : Index(['Sex', 'Pclass', 'SibSp', 'Parch', 'Embarked'], dtype='object')
# Error Rate : 13.88

# %%
dot_data = tree.export_graphviz(dtc, out_file = None, feature_names = train_data.columns.values)

graph = graphviz.Source(dot_data)
graph.format = 'png'
graph.view(filename='digraph', directory='./')
# Out:
# 'digraph.png'
